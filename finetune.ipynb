# %%
# %cd stable-audio-tools

command = (
    "python train.py"
    " --dataset-config ../dataset_config.json"
    " --model-config ../model/model_config.json"
    " --name stable_audio_open_finetune_kshmr"
    " --save-dir ../checkpoints"
    " --checkpoint-every 2000"
    " --batch-size 32"
    " --num-gpus 1"
    " --precision 16-mixed"
    " --seed 42"
    " --pretrained-ckpt-path ../model/model.ckpt"
)

# !{command}
# Out:
# /mnt/beegfs/projects/sketching_audio/Dev/stable-audio/stable-audio-tools
# /mnt/beegfs/home/koroshinadze/miniconda3/envs/stableaudio/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Found 14382 files
# /mnt/beegfs/home/koroshinadze/miniconda3/envs/stableaudio/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# No module named 'flash_attn'
# ...
